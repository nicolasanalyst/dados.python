# %%
#importar
import pandas as pd
import seaborn as srn
import statistics as sts

# %%
#importar dados
dataset = pd.read_csv("Churn.csv", sep=";")
#visualizar 
dataset.head()
# Out:
#    X0   X1  X2        X3  X4  X4.1        X6  X7  X8  X9         X10  X11
# 0   1  619  RS  Feminino  42     2         0   1   1   1  10134888.0    1
# 1   2  608  SC  Feminino  41     1   8380786   1   0   1  11254258.0    0
# 2   3  502  RS  Feminino  42     8   1596608   3   1   0  11393157.0    1
# 3   4  699  RS  Feminino  39     1         0   2   0   0   9382663.0    0
# 4   5  850  SC  Feminino  43     2  12551082   1   1   1    790841.0    0

# %%
#tamanho
dataset.shape
# Out:
# (999, 12)

# %%
dataset.columns = ["id", "score", "Estado", "Genero", "Idade", "patrímonio", "Saldo", "produtos",
                   "temcartcredito", "Ativo", "Salario", "Saiu"]

# %%
#visualizar
dataset.head()
# Out:
#    id  score Estado    Genero  Idade  patrímonio     Saldo  produtos  \
# 0   1    619     RS  Feminino     42           2         0         1
# 1   2    608     SC  Feminino     41           1   8380786         1
# 2   3    502     RS  Feminino     42           8   1596608         3
# 3   4    699     RS  Feminino     39           1         0         2
# 4   5    850     SC  Feminino     43           2  12551082         1
#
#    temcartcredito  Ativo     Salario  Saiu
# 0               1      1  10134888.0     1
# 1               0      1  11254258.0     0
# 2               1      0  11393157.0     1
# 3               0      0   9382663.0     0
# 4               1      1    790841.0     0

# %%
#explorar dados categoricos
#estado
agrupado = dataset.groupby(['Estado']).size()
agrupado
# Out:
# Estado
# PR    257
# RP      1
# RS    478
# SC    258
# SP      4
# TD      1
# dtype: int64

# %%
#gerar grafico
agrupado.plot.bar(color = "blue")
# Out:
# <AxesSubplot:xlabel='Estado'>

# %%
#genero
agrupado = dataset.groupby(["Genero"]).size()
agrupado
# Out:
# Genero
# F              2
# Fem            1
# Feminino     461
# M              6
# Masculino    521
# dtype: int64

# %%
#gerar grafico
agrupado.plot.bar(color = "blue")
# Out:
# <AxesSubplot:xlabel='Genero'>

# %%
dataset["score"].describe()
# Out:
# count    999.000000
# mean     648.621622
# std       98.264219
# min      376.000000
# 25%      580.000000
# 50%      653.000000
# 75%      721.000000
# max      850.000000
# Name: score, dtype: float64

# %%
srn.boxplot(dataset["score"]).set_title("grafico finaceiro")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'grafico finaceiro')

# %%
srn.distplot(dataset["score"]).set_title("grafico financeiro")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'grafico financeiro')

# %%
dataset["Idade"].describe()
# Out:
# count    999.000000
# mean      38.902903
# std       11.401912
# min      -20.000000
# 25%       32.000000
# 50%       37.000000
# 75%       44.000000
# max      140.000000
# Name: Idade, dtype: float64

# %%
srn.boxplot(dataset["Idade"]).set_title("idade funcionarios")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'idade funcionarios')

# %%
srn.distplot(dataset["Idade"]).set_title("idade funcionarios")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'idade funcionarios')

# %%
dataset["Saldo"].describe()
# Out:
# count    9.990000e+02
# mean     7.164928e+06
# std      6.311840e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      8.958835e+06
# 75%      1.258684e+07
# max      2.117743e+07
# Name: Saldo, dtype: float64

# %%
srn.boxplot(dataset["Saldo"]).set_title("saldo clientes")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'saldo clientes')

# %%
srn.distplot(dataset["Saldo"]).set_title("saldo clientes")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'saldo clientes')

# %%
srn.boxplot(dataset["Salario"]).set_title("salarios funcionarios")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'salarios funcionarios')

# %%
srn.distplot(dataset["Salario"]).set_title("salarios funcionarios")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'salarios funcionarios')

# %%
#contamos valores NAN
#Genero e Salario
dataset.isnull().sum()
# Out:
# id                0
# score             0
# Estado            0
# Genero            8
# Idade             0
# patrímonio        0
# Saldo             0
# produtos          0
# temcartcredito    0
# Ativo             0
# Salario           7
# Saiu              0
# dtype: int64

# %%
agrupado = dataset.groupby(["score"]).size()
agrupado
# Out:
# score
# 376     2
# 411     1
# 413     1
# 416     2
# 417     1
#        ..
# 842     1
# 844     1
# 846     1
# 848     1
# 850    19
# Length: 354, dtype: int64

# %%
agrupado.plot.bar(color = "blue")
# Out:
# <AxesSubplot:xlabel='score'>
